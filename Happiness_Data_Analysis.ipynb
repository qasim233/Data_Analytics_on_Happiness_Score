# %%
#importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading all datasets in pandas dataframe

data_2015 = pd.read_csv('2015.csv')
data_2016 = pd.read_csv('2016.csv')
data_2017 = pd.read_csv('2017.csv')
data_2018 = pd.read_csv('2018.csv')
data_2019 = pd.read_csv('2019.csv')

# %%
data_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#Checking for missing values in all datasets
all_datasets = [data_2015, data_2016, data_2017, data_2018, data_2019]
for data in all_datasets:
    
    print(data.isnull().sum())
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64
# Country                          0
# ...

# %%
#counting total countries
print(data_2015['Country'].nunique())
# Out:
# 158

# %%
#Retreiving list of countries of 2015 that have health (life expectancy) value between 0.5 and 1

countries_2015 = data_2015[(data_2015['Health (Life Expectancy)'] > 0.5) & (data_2015['Health (Life Expectancy)'] < 1)]
countries_2015 = countries_2015['Country']
countries_2015
# Out:
# 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 131      Sri Lanka
# 133       Bulgaria
# 134          Egypt
# 144       Cambodia
# 155          Syria
# Name: Country, Length: 113, dtype: object

# %%
#Retreiving list of top 10 countries of 2016 that have highest health (life expectancy)

countries_2016 = data_2016.sort_values(by='Health (Life Expectancy)', ascending=False).head(10)
countries_2016 = countries_2016[['Country', 'Health (Life Expectancy)']]
countries_2016
# Out:
#         Country  Health (Life Expectancy)
# 74    Hong Kong                   0.95277
# 21    Singapore                   0.94719
# 52        Japan                   0.91491
# 57  South Korea                   0.88645
# 36        Spain                   0.87896
# 2       Iceland                   0.86733
# 1   Switzerland                   0.86303
# 8     Australia                   0.85120
# 49        Italy                   0.85102
# 10       Israel                   0.84917

# %%
data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#Display the mean Happiness Score of the countries grouped by the Region for any year
#lets take 2019

mean_score = data_2019.groupby('Country or region')['Healthy life expectancy'].mean()
mean_score
# Out:
# Country or region
# Afghanistan    0.361
# Albania        0.874
# Algeria        0.785
# Argentina      0.881
# Armenia        0.815
#                ...
# Venezuela      0.805
# Vietnam        0.851
# Yemen          0.463
# Zambia         0.426
# Zimbabwe       0.433
# Name: Healthy life expectancy, Length: 156, dtype: float64

# %%
data_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
#Rename all columns of all datasets to have same column names
data_2015.columns = ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity', 'Dystopia Residual']
data_2016.columns = ['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity', 'Dystopia Residual']
data_2017.columns = ['Country', 'Happiness Rank', 'Happiness Score', 'Whisker High', 'Whisker Low', 'Economy', 'Family', 'Health', 'Freedom', 'Generosity', 'Trust', 'Dystopia Residual']
data_2018.columns = ['Happiness Rank', 'Country', 'Happiness Score', 'Economy', 'Family', 'Health', 'Freedom', 'Generosity', 'Trust']
data_2019.columns = ['Happiness Rank', 'Country', 'Happiness Score', 'Economy', 'Family', 'Health', 'Freedom', 'Generosity', 'Trust']

# %%
data_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy   Family   Health  Freedom  \
# 0              7.587         0.03411  1.39651  1.34951  0.94143  0.66557
# ...

# %%
#Checking for outliers in all datasets
for data in all_datasets:
    data.boxplot()
    plt.figure(figsize=(5, 5))
    plt.show()

# %%
#remove all outliers
for data in all_datasets:
    for column in data.columns:
        if data[column].dtype != 'object':
            q1 = data[column].quantile(0.25)
            q3 = data[column].quantile(0.75)
            iqr = q3 - q1
            lower_bound = q1 - (1.5 * iqr)
            upper_bound = q3 + (1.5 * iqr)
            data[column] = data[column][(data[column] > lower_bound) & (data[column] < upper_bound)]

# %%
data_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
#Analyze if there is any relationship between the Happiness Score and Economy (GDP per Capita) of the country for any year.

data_2015.plot(x='Happiness Score', y='Economy', kind='scatter')
plt.show()

# %%
#correlation between Happiness Score and Economy for 2015
data_2015['Happiness Score'].corr(data_2015['Economy'])
# Out:
# 0.7809655268660212

# %% [markdown]
# positive correlation exist between Happiness Score and Economy

# %%
"""Combine the datasets from 2015-2019 to construct 1 dataframe that
contains the following columns. Country, Region, Year (coming from
the respective dataset) and Happiness Score for each year as a new
column
"""

data_2015['Year'] = 2015
data_2016['Year'] = 2016
data_2017['Year'] = 2017
data_2018['Year'] = 2018
data_2019['Year'] = 2019

data = pd.concat([data_2015, data_2016, data_2017, data_2018, data_2019])
data = data[['Country', 'Year', 'Happiness Score']]
data
# Out:
#                       Country  Year  Happiness Score
# 0                 Switzerland  2015            7.587
# 1                     Iceland  2015            7.561
# 2                     Denmark  2015            7.527
# 3                      Norway  2015            7.522
# 4                      Canada  2015            7.427
# ..                        ...   ...              ...
# 151                    Rwanda  2019            3.334
# 152                  Tanzania  2019            3.231
# 153               Afghanistan  2019            3.203
# 154  Central African Republic  2019            3.083
# 155               South Sudan  2019            2.853
#
# [782 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Happiness Score'], dtype='object')

# %%
data.pivot_table(index=['Country'], columns='Year', values='Happiness Score')
# Out:
# Year          2015   2016   2017   2018   2019
# Country
# Afghanistan  3.575  3.360  3.794  3.632  3.203
# Albania      4.959  4.655  4.644  4.586  4.719
# Algeria      5.605  6.355  5.872  5.295  5.211
# Angola       4.033  3.866  3.795  3.795    NaN
# Argentina    6.574  6.650  6.599  6.388  6.086
# ...            ...    ...    ...    ...    ...
# Venezuela    6.810  6.084  5.250  4.806  4.707
# Vietnam      5.360  5.061  5.074  5.103  5.175
# Yemen        4.077  3.724  3.593  3.355  3.380
# Zambia       5.129  4.795  4.514  4.377  4.107
# Zimbabwe     4.610  4.193  3.875  3.692  3.663
#
# [170 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Happiness Score'], dtype='object')

# %%
"""For any 2 countries of your choice draw a line chart (x-axis contains
the years from the dataframe constructed in part g and y-axis
contains the Happiness Score values for the respective years).
Identify the trend"""

countries = data[(data['Country'] == 'India') | (data['Country'] == 'Pakistan')]
countries = countries.pivot_table(index=['Country'], columns='Year', values='Happiness Score')

countries.T.plot()
plt.xlabel('Year')
plt.ylabel('Happiness Score')
plt.title('Happiness Score of India and Pakistan')
plt.xticks(np.arange(2015, 2020))
plt.grid(True)
plt.show()

# %%
#For the year 2015, identify the regions that have an Economy (GDP per Capita) value less than 0.5

regions = data_2015[data_2015['Economy'] < 0.5]
regions = regions[['Region', 'Economy']]
regions
# Out:
#                           Region  Economy
# 76    Central and Eastern Europe  0.47428
# 84            Sub-Saharan Africa  0.47038
# 90            Sub-Saharan Africa  0.18847
# 93            Sub-Saharan Africa  0.08308
# 96            Sub-Saharan Africa  0.37545
# 105   Central and Eastern Europe  0.39047
# 108                Southern Asia  0.39753
# 114           Sub-Saharan Africa  0.27100
# 115           Sub-Saharan Africa  0.07120
# 118  Latin America and Caribbean  0.26673
# 119           Sub-Saharan Africa  0.00000
# 120                Southern Asia  0.35997
# 121           Sub-Saharan Africa  0.19073
# 122           Sub-Saharan Africa  0.33024
# 123           Sub-Saharan Africa  0.45407
# 124           Sub-Saharan Africa  0.36471
# 125           Sub-Saharan Africa  0.44025
# 128            Southeastern Asia  0.27108
# 130           Sub-Saharan Africa  0.01604
# 132           Sub-Saharan Africa  0.42250
# 137           Sub-Saharan Africa  0.26074
# ...

# %%
#Datatypes of all columns in 2015

data_2015.dtypes
# Out:
# Country               object
# Region                object
# Happiness Rank         int64
# Happiness Score      float64
# Standard Error       float64
# Economy              float64
# Family               float64
# Health               float64
# Freedom              float64
# Trust                float64
# Generosity           float64
# Dystopia Residual    float64
# Year                   int64
# dtype: object

# %%
numeric_cols = data_2015.iloc[:, 2:12]
numeric_cols.dtypes
# Out:
# Happiness Rank         int64
# Happiness Score      float64
# Standard Error       float64
# Economy              float64
# Family               float64
# Health               float64
# Freedom              float64
# Trust                float64
# Generosity           float64
# Dystopia Residual    float64
# dtype: object

# %%
#Identify which 2 variables have the highest correlations across all the countries for the years 2015 and 2016.

highest_corr = numeric_cols.corr().unstack().sort_values(ascending=False).drop_duplicates()
highest_corr
# Out:
# Happiness Rank     Happiness Rank       1.000000
# Health             Economy              0.816478
# Happiness Score    Economy              0.780966
#                    Family               0.728691
# Health             Happiness Score      0.724200
# Family             Economy              0.623952
# Happiness Score    Freedom              0.568211
#                    Dystopia Residual    0.497575
# Health             Family               0.489229
# Family             Freedom              0.471066
# Freedom            Generosity           0.393145
#                    Trust                0.372114
# Economy            Freedom              0.370300
# Health             Freedom              0.360477
# Trust              Happiness Score      0.320460
# Generosity         Trust                0.232794
# Happiness Rank     Standard Error       0.215950
# Happiness Score    Generosity           0.210432
# Economy            Trust                0.187944
# ...

# %% [markdown]
# Health and economy has the highest postive correlation. Seconly Happiness Score and Economy has 2nd highest postive correlation.
